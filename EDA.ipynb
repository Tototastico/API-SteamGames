# %% [markdown]
# <div style="text-align: center;">
#   <h1>Games EDA</h1>
# </div>

# %% [markdown]
# Vamos a hacer un pequeño EDA sobre el dataset de juegos, ya que necesitamos conocer un poco mas nuestros datos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_games = pd.read_parquet('clean_games.parquet.gzip') # Leemos el archivo
df_games.head() #Damos un vistazo rapido de los juegos
# Out:
#    publisher      genres             app_name  price  early_access      id  \
# 0  Kotoshiro      Action  lost summoner kitty   4.99             0  761140
# 0  Kotoshiro      Casual  lost summoner kitty   4.99             0  761140
# 0  Kotoshiro       Indie  lost summoner kitty   4.99             0  761140
# 0  Kotoshiro  Simulation  lost summoner kitty   4.99             0  761140
# 0  Kotoshiro    Strategy  lost summoner kitty   4.99             0  761140
#
#    year
# 0  2018
# 0  2018
# 0  2018
# 0  2018
# 0  2018

# %%
df_games.groupby('genres').count()['id']
# Out:
# genres
# Accounting                       7
# Action                       11320
# Adventure                     8242
# Animation &amp; Modeling       183
# Audio Production                93
# Casual                        8282
# Design &amp; Illustration      460
# Early Access                  1462
# Education                      125
# Free to Play                  2031
# Indie                        15858
# Massively Multiplayer         1108
# Photo Editing                   77
# RPG                           5479
# Racing                        1083
# Simulation                    6699
# Software Training              105
# Sports                        1257
# Strategy                      6957
# Utilities                      340
# Video Production               116
# Web Publishing                 268
# []                            3282
# Name: id, dtype: int64

# %%
# Configura el tamaño del gráfico si es necesario
plt.figure(figsize=(10, 6))

# Crea el gráfico de barras
conteo_genero = df_games['genres'].value_counts().sort_values(ascending=False)
conteo_genero.plot(kind='bar',color='skyblue')

# Personaliza los ejes y el título
plt.xlabel('Género')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por Género')

# Muestra el gráfico
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='price', data=df_games)
plt.ylabel('Precio')
plt.title('Outlier de precios')
# Out:
# Text(0.5, 1.0, 'Outlier de precios')

# %%
empresas = df_games['publisher'].value_counts().sort_values(ascending=False).to_dict()
empresas = dict(list(empresas.items())[:10])

# %%
etiquetas = list(empresas.keys())
valores = list(empresas.values())

# Configura el tamaño del gráfico si es necesario
plt.figure(figsize=(10, 6))
sns.barplot(x=etiquetas, y=valores, palette="viridis")
# Personaliza los ejes y el título
plt.xlabel('Género')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por Género')

plt.xticks(rotation=45)

# Muestra el gráfico
plt.show()

# %%
# Configura el tamaño del gráfico si es necesario
plt.figure(figsize=(10, 6))
sns.lineplot(df_games['year'].value_counts(), palette="viridis")
# Personaliza los ejes y el título
plt.xlabel('Año')
plt.ylabel('Cantidad de juegos')
plt.title('Cantidad de juegos por año')

plt.xticks(rotation=45)

# Muestra el gráfico
plt.show()
# Out:
# C:\Users\cf550\AppData\Local\Temp\ipykernel_18388\2186654290.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(df_games['year'].value_counts(), palette="viridis")

# %%
df_games.groupby
# Out:
# 8.394214359207343

# %%
# Configura el tamaño del gráfico si es necesario
plt.figure(figsize=(10, 6))
sns.lineplot(df_games['year'].value_counts(), palette="viridis")
# Personaliza los ejes y el título
plt.xlabel('Año')
plt.ylabel('Cantidad de juegos')
plt.title('Cantidad de juegos por año')

plt.xticks(rotation=45)

# Muestra el gráfico
plt.show()
# Out:
#           publisher      genres             app_name  price  early_access  \
# 0         Kotoshiro      Action  lost summoner kitty   4.99             0
# 0         Kotoshiro      Casual  lost summoner kitty   4.99             0
# 0         Kotoshiro       Indie  lost summoner kitty   4.99             0
# 0         Kotoshiro  Simulation  lost summoner kitty   4.99             0
# 0         Kotoshiro    Strategy  lost summoner kitty   4.99             0
# ...             ...         ...                  ...    ...           ...
# 32132  Laush Studio      Racing        russian roads   1.99             0
# 32132  Laush Studio  Simulation        russian roads   1.99             0
# 32133      SIXNAILS      Casual  exit 2 - directions   4.99             0
# 32133      SIXNAILS       Indie  exit 2 - directions   4.99             0
# 32134          None          []          maze run vr   4.99             1
#
#            id  year
# 0      761140  2018
# 0      761140  2018
# ...
