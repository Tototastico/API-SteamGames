# %%
# Out:
# ['240660',
#  '598530',
#  '731940',
#  '316970',
#  '437020',
#  '516840',
#  '382050',
#  '501510',
#  '671810',
#  '496460',
#  '326622',
#  '455370',
#  '338260',
#  '13000',
#  '522490',
#  '264220',
#  '397010',
#  '679090',
#  '291330',
#  '434780',
#  '211420',
#  '396620',
#  '283680',
#  '331160',
#  '688020',
#  '755560',
#  '377200',
#  '374620',
#  '586280',
#  '607670',
#  '215533',
#  '749220',
#  '386110',
#  '270570',
#  '565002',
#  '312310',
#  '397950',
#  '467390',
#  '310890',
#  '323430',
#  '516790',
#  '594440',
#  '496320',
#  '552280',
#  '674590',
#  '422250',
#  '236730',
#  '657690',
#  '342560',
#  '506870',
#  '680070',
#  '451200',
#  '335430',
#  '419479',
#  '643810',
#  '354560',
#  '701310',
#  '562230',
#  '435040',
#  '704490',
#  '461740',
#  '351480',
#  '514220',
#  '323670',
#  '272510',
#  '573290',
#  '250600',
#  '656400',
#  '351340',
#  '311080',
#  '375510',
#  '527790',
#  '47120',
#  '472740',
#  '501590',
#  '768853',
#  '571310',
# ...
